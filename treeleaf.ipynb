# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/New Bank_loan_data (1) (2) (1).csv')

# %%
df.head()
# Out:
#    ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  Education  \
# 0   1   25      M           1    49.0     91107       4    1.6          1
# 1   2   45      M          19    34.0     90089       3    1.5          1
# 2   3   39      M          15    11.0     94720       1    1.0          1
# 3   4   35      M           9   100.0     94112       1    2.7          2
# 4   5   35      M           8    45.0     91330       4    1.0          2
#
#    Mortgage Home Ownership Personal Loan  Securities Account  CD Account  \
# 0         0     Home Owner             0                   1           0
# 1         0           Rent             0                   1           0
# 2         0           Rent             0                   0           0
# 3         0           Rent             0                   0           0
# 4         0           Rent             0                   0           0
#
#    Online  CreditCard
# 0     0.0           0
# 1     0.0           0
# ...

# %%
df.shape
# Out:
# (5000, 16)

# %%
df['Home Ownership'].nunique()
# Out:
# 3

# %%
df['Home Ownership'].value_counts()
# Out:
# Home Mortage    1705
# Home Owner      1156
# Rent             950
# Name: Home Ownership, dtype: int64

# %%
df_has_home = df[df['Home Ownership'].isna() & (df['Mortgage'] != 0)]
df_has_home
# Out:
#         ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 52      53   30      M           6    72.0     94005       1   0.10
# 327    328   58      M          32   114.0     91330       2   2.00
# 343    344   35      M           5    22.0     93407       1   0.67
# 373    374   49      M          25    20.0     90291       4   1.00
# 491    492   42      M          18    34.0     92115       4   0.30
# ...    ...  ...    ...         ...     ...       ...     ...    ...
# 4987  4988   48    NaN          23    43.0     93943       3   1.70
# 4988  4989   34    NaN           8    85.0     95134       1   2.50
# 4990  4991   55    NaN          25    58.0     95023       4   2.00
# 4991  4992   51    NaN          25    92.0     91330       1   1.90
# 4996  4997   30    NaN           4    15.0     92037       4   0.40
#
#       Education  Mortgage Home Ownership Personal Loan  Securities Account  \
# ...

# %%
df.isna().sum()
# Out:
# ID                       0
# Age                      0
# Gender                1596
# Experience               0
# Income                  67
# ZIP Code                 0
# Family                   0
# CCAvg                    0
# Education                0
# Mortgage                 0
# Home Ownership        1189
# Personal Loan            0
# Securities Account       0
# CD Account               0
# Online                  40
# CreditCard               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_income_null = df[df['Income'].isna() | (df['Income'] == 0)]
df_income_null.head()
# Out:
#       ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  Education  \
# 29    30   38      M          13     NaN     94104       1    3.3          2
# 38    39   42      M          18     NaN     94114       3    5.0          3
# 78    79    0      M          30     NaN     93305       2    2.6          3
# 199  200   36      M          11     NaN     92152       1    5.1          3
# 324  325   56      M          30     NaN     90089       4    6.1          1
#
#      Mortgage Home Ownership Personal Loan  Securities Account  CD Account  \
# 29          0           Rent             1                   0           1
# 38          0           Rent             1                   1           1
# 78          0           Rent             1                   0           0
# 199         0   Home Mortage             1                   0           1
# 324         0           Rent             1                   0           0
#
#      Online  CreditCard
# 29      1.0           1
# ...

# %%
df_income_null_sorted = df_income_null.sort_values(by='Age')
df_income_null_sorted
# Out:
#         ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 78      79    0      M          30     NaN     93305       2    2.6
# 4345  4346   26      O           1     NaN     94608       2    4.2
# 3084  3085   26      M           0     NaN     90028       3    0.7
# 2951  2952   26      F           2     NaN     94720       2    2.4
# 1022  1023   27      M           3     NaN     95605       1    3.3
# ...    ...  ...    ...         ...     ...       ...     ...    ...
# 3822  3823   63      F          33     NaN     91768       4    9.0
# 2061  2062   63      M          38     NaN     93950       4    4.9
# 4642  4643   65      O          40     NaN     95616       4    6.6
# 1411  1412   65      F          39     NaN     91302       1    5.4
# 3217  3218   65      F          39     NaN     93022       4    4.1
#
#       Education  Mortgage Home Ownership Personal Loan  Securities Account  \
# ...

# %%
df_age=df[df['Age']==0]

# %%
df_age
# Out:
#         ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 78      79    0      M          30     NaN     93305       2    2.6
# 1583  1584    0      F          36   184.0     92028       4    2.3
#
#       Education  Mortgage Home Ownership Personal Loan  Securities Account  \
# 78            3         0           Rent             1                   0
# 1583          2       342           Rent             1                   0
#
#       CD Account  Online  CreditCard
# 78             0     0.0           0
# 1583           1     NaN           1

# %%
df_gender = df[df['Gender'].isna()]
df_gender
# Out:
#         ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 73      74   41    NaN          16    85.0     94606       1    4.0
# 74      75   28    NaN           3   135.0     94611       2    3.3
# 76      77   58    NaN          32    12.0     91320       3    0.3
# 77      78   46    NaN          20    29.0     92220       3    0.5
# 107    108   42    NaN          18    43.0     92037       1    0.7
# ...    ...  ...    ...         ...     ...       ...     ...    ...
# 4995  4996   29    NaN           3    40.0     92697       1    1.9
# 4996  4997   30    NaN           4    15.0     92037       4    0.4
# 4997  4998   63    NaN          39    24.0     93023       2    0.3
# 4998  4999   65    NaN          40    49.0     90034       3    0.5
# 4999  5000   28    NaN           4    83.0     92612       3    0.8
#
#       Education  Mortgage Home Ownership Personal Loan  Securities Account  \
# ...

# %%
df.describe()
# Out:
#                 ID          Age   Experience       Income      ZIP Code  \
# count  5000.000000  5000.000000  5000.000000  4933.000000   5000.000000
# mean   2500.500000    46.008200    20.104600    72.758159  93152.503000
# std    1443.520003    25.444898    11.467954    45.425519   2121.852197
# min       1.000000     0.000000    -3.000000     8.000000   9307.000000
# 25%    1250.750000    35.000000    10.000000    39.000000  91911.000000
# 50%    2500.500000    45.000000    20.000000    63.000000  93437.000000
# 75%    3750.250000    55.000000    30.000000    95.000000  94608.000000
# max    5000.000000   978.000000    43.000000   224.000000  96651.000000
#
#             Family        CCAvg    Education     Mortgage  Securities Account  \
# count  5000.000000  5000.000000  5000.000000  5000.000000         5000.000000
# mean      2.396400     1.937938     1.880600    56.498800            0.104400
# std       1.147663     1.747659     0.839812   101.713802            0.305809
# ...

# %%
df['Gender'].nunique()
# Out:
# 5

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F', 'O', nan, '#', '-'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# M    1677
# F    1607
# O      96
# -      21
# #       3
# Name: Gender, dtype: int64

# %%
df['Gender'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Name: Gender, Length: 5000, dtype: bool

# %%
df['']
