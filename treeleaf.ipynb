# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/New Bank_loan_data (1) (2) (1).csv')

# %%
df.head()
# Out:
#    ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  Education  \
# 0   1   25      M           1    49.0     91107       4    1.6          1
# 1   2   45      M          19    34.0     90089       3    1.5          1
# 2   3   39      M          15    11.0     94720       1    1.0          1
# 3   4   35      M           9   100.0     94112       1    2.7          2
# 4   5   35      M           8    45.0     91330       4    1.0          2
#
#    Mortgage Home Ownership Personal Loan  Securities Account  CD Account  \
# 0         0     Home Owner             0                   1           0
# 1         0           Rent             0                   1           0
# 2         0           Rent             0                   0           0
# 3         0           Rent             0                   0           0
# 4         0           Rent             0                   0           0
#
#    Online  CreditCard
# 0     0.0           0
# 1     0.0           0
# ...

# %%
df.shape
# Out:
# (5000, 16)

# %%
df.dtypes
# Out:
# ID                      int64
# Age                     int64
# Gender                 object
# Experience              int64
# Income                float64
# ZIP Code                int64
# Family                  int64
# CCAvg                 float64
# Education               int64
# Mortgage                int64
# Home Ownership         object
# Personal Loan          object
# Securities Account      int64
# CD Account              int64
# Online                float64
# CreditCard              int64
# dtype: object

# %%
df.describe()
# Out:
#                 ID          Age   Experience       Income      ZIP Code  \
# count  5000.000000  5000.000000  5000.000000  4933.000000   5000.000000
# mean   2500.500000    46.008200    20.104600    72.758159  93152.503000
# std    1443.520003    25.444898    11.467954    45.425519   2121.852197
# min       1.000000     0.000000    -3.000000     8.000000   9307.000000
# 25%    1250.750000    35.000000    10.000000    39.000000  91911.000000
# 50%    2500.500000    45.000000    20.000000    63.000000  93437.000000
# 75%    3750.250000    55.000000    30.000000    95.000000  94608.000000
# max    5000.000000   978.000000    43.000000   224.000000  96651.000000
#
#             Family        CCAvg    Education     Mortgage  Securities Account  \
# count  5000.000000  5000.000000  5000.000000  5000.000000         5000.000000
# mean      2.396400     1.937938     1.880600    56.498800            0.104400
# std       1.147663     1.747659     0.839812   101.713802            0.305809
# ...

# %%
df.corr()
# Out:
# <ipython-input-7-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           ID       Age  Experience    Income  ZIP Code  \
# ID                  1.000000 -0.022173   -0.008326 -0.022748  0.013432
# Age                -0.022173  1.000000    0.439132  0.026946 -0.022257
# Experience         -0.008326  0.439132    1.000000 -0.049319 -0.028626
# Income             -0.022748  0.026946   -0.049319  1.000000 -0.018415
# ZIP Code            0.013432 -0.022257   -0.028626 -0.018415  1.000000
# Family             -0.016797 -0.017867   -0.052563 -0.167167  0.011778
# CCAvg              -0.024675  0.011776   -0.050077  0.643782 -0.004061
# Education           0.022141  0.024320    0.014071 -0.204080 -0.017598
# Mortgage           -0.013920  0.021672   -0.010582  0.201489  0.007383
# ...

# %% [markdown]
# Checking for missing values

# %%
df.isna().sum()
# Out:
# ID                       0
# Age                      0
# Gender                1596
# Experience               0
# Income                  67
# ZIP Code                 0
# Family                   0
# CCAvg                    0
# Education                0
# Mortgage                 0
# Home Ownership        1189
# Personal Loan            0
# Securities Account       0
# CD Account               0
# Online                  40
# CreditCard               0
# dtype: int64

# %% [markdown]
# checking for duplicated values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Home Ownership'].unique()
# Out:
# array(['Home Owner', 'Rent', 'Home Mortage', nan], dtype=object)

# %%
df['Gender'] = df['Gender'].replace(np.nan, 'not specified')
df['Gender'] = df['Gender'].replace(['#', '-'], 'not specified')

# %%
df['Gender'].isna().sum()
# Out:
# 0

# %%
df_homeowner=df.loc[(df['Home Ownership']=='Home Owner') & (df['Mortgage']!=0)]
df_homerenter=df.loc[(df['Home Ownership']=='Rent') & (df['Mortgage']!=0)]

# %%
df_homeowner.shape
# Out:
# (378, 16)

# %%
df_homerenter.shape
# Out:
# (274, 16)

# %%
df.loc[(df['Home Ownership'].isna()) & (df['Mortgage'] != 0), 'Home Ownership'] = 'Home Owner'

# %%
df.isna().sum()
# Out:
# ID                      0
# Age                     0
# Gender                  0
# Experience              0
# Income                 67
# ZIP Code                0
# Family                  0
# CCAvg                   0
# Education               0
# Mortgage                0
# Home Ownership        841
# Personal Loan           0
# Securities Account      0
# CD Account              0
# Online                 40
# CreditCard              0
# dtype: int64

# %%
df_age
# Out:
#         ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 78      79    0      M          30     NaN     93305       2    2.6
# 1583  1584    0      F          36   184.0     92028       4    2.3
#
#       Education  Mortgage Home Ownership Personal Loan  Securities Account  \
# 78            3         0           Rent             1                   0
# 1583          2       342           Rent             1                   0
#
#       CD Account  Online  CreditCard
# 78             0     0.0           0
# 1583           1     NaN           1

# %%
df_gender = df[df['Gender'].isna()]
df_gender
# Out:
#         ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 73      74   41    NaN          16    85.0     94606       1    4.0
# 74      75   28    NaN           3   135.0     94611       2    3.3
# 76      77   58    NaN          32    12.0     91320       3    0.3
# 77      78   46    NaN          20    29.0     92220       3    0.5
# 107    108   42    NaN          18    43.0     92037       1    0.7
# ...    ...  ...    ...         ...     ...       ...     ...    ...
# 4995  4996   29    NaN           3    40.0     92697       1    1.9
# 4996  4997   30    NaN           4    15.0     92037       4    0.4
# 4997  4998   63    NaN          39    24.0     93023       2    0.3
# 4998  4999   65    NaN          40    49.0     90034       3    0.5
# 4999  5000   28    NaN           4    83.0     92612       3    0.8
#
#       Education  Mortgage Home Ownership Personal Loan  Securities Account  \
# ...

# %%
df.describe()
# Out:
#                 ID          Age   Experience       Income      ZIP Code  \
# count  5000.000000  5000.000000  5000.000000  4933.000000   5000.000000
# mean   2500.500000    46.008200    20.104600    72.758159  93152.503000
# std    1443.520003    25.444898    11.467954    45.425519   2121.852197
# min       1.000000     0.000000    -3.000000     8.000000   9307.000000
# 25%    1250.750000    35.000000    10.000000    39.000000  91911.000000
# 50%    2500.500000    45.000000    20.000000    63.000000  93437.000000
# 75%    3750.250000    55.000000    30.000000    95.000000  94608.000000
# max    5000.000000   978.000000    43.000000   224.000000  96651.000000
#
#             Family        CCAvg    Education     Mortgage  Securities Account  \
# count  5000.000000  5000.000000  5000.000000  5000.000000         5000.000000
# mean      2.396400     1.937938     1.880600    56.498800            0.104400
# std       1.147663     1.747659     0.839812   101.713802            0.305809
# ...

# %%
df['Gender'].nunique()
# Out:
# 5

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F', 'O', nan, '#', '-'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# M    1677
# F    1607
# O      96
# -      21
# #       3
# Name: Gender, dtype: int64

# %%
df['Gender'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Name: Gender, Length: 5000, dtype: bool

# %%
df.head()
# Out:
#    ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  Education  \
# 0   1   25      M           1    49.0     91107       4    1.6          1
# 1   2   45      M          19    34.0     90089       3    1.5          1
# 2   3   39      M          15    11.0     94720       1    1.0          1
# 3   4   35      M           9   100.0     94112       1    2.7          2
# 4   5   35      M           8    45.0     91330       4    1.0          2
#
#    Mortgage Home Ownership Personal Loan  Securities Account  CD Account  \
# 0         0     Home Owner             0                   1           0
# 1         0           Rent             0                   1           0
# 2         0           Rent             0                   0           0
# 3         0           Rent             0                   0           0
# 4         0           Rent             0                   0           0
#
#    Online  CreditCard
# 0     0.0           0
# 1     0.0           0
# ...
